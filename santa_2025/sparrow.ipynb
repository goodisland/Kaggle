# %% [markdown]
# ## Goal
# Pack 14 Christmas tree polygons into the smallest square. Target score: 0.3696
#
# Score formula: `max(width, height)^2 / N`

# %%
# !git clone https://github.com/SmartManoj/sparrow
# Out:
# Cloning into 'sparrow'...
# remote: Enumerating objects: 4699, done.
# remote: Counting objects: 100% (617/617), done.
# remote: Compressing objects: 100% (309/309), done.
# remote: Total 4699 (delta 388), reused 326 (delta 306), pack-reused 4082 (from 3)
# Receiving objects: 100% (4699/4699), 11.00 MiB | 28.88 MiB/s, done.
# Resolving deltas: 100% (3291/3291), done.

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: latest update on 2025-12-11, rust version 1.92.0 (ded5c06cf 2025-12-08)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#  10.3 MiB /  10.3 MiB (100 %)   9.1 MiB/s in  1s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  20.5 MiB /  20.5 MiB (100 %)   4.5 MiB/s in  4s
# info: installing component 'rust-std'
#  28.0 MiB /  28.0 MiB (100 %)   8.5 MiB/s in  3s
# info: installing component 'rustc'
#  74.3 MiB /  74.3 MiB (100 %)   9.6 MiB/s in  7s
# info: installing component 'rustfmt'
# info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#
#   stable-x86_64-unknown-linux-gnu installed - rustc 1.92.0 (ded5c06cf 2025-12-08)
#
#
# Rust is installed now. Great!
#
# To get started you may need to restart your current shell.
# This would reload your PATH environment variable to include
# Cargo's bin directory ($HOME/.cargo/bin).
#
# To configure your current shell, you need to source
# the corresponding env file under $HOME/.cargo.
#
# This is usually done by running one of the following (note the leading DOT):
# . "$HOME/.cargo/env"            # For sh/bash/zsh/ash/dash/pdksh
# source "$HOME/.cargo/env.fish"  # For fish
# source $"($nu.home-path)/.cargo/env.nu"  # For nushell

# %%
 # !rustup default nightly
# Out:
# /bin/bash: line 1: rustup: command not found

# %%
import os
os.environ['PATH']+=':/root/.cargo/bin'

# %% [markdown]
# ### 1. Create input file

# %%
data = '''
{
  "name": "n14_h2280",
  "items": [{
    "id": 0,
    "demand": 14,
    "shape": {
      "type": "simple_polygon",
      "data": [[0,800],[125,500],[62.5,500],[200,250],[100,250],[350,0],[75,0],[75,-200],[-75,-200],[-75,0],[-350,0],[-100,250],[-200,250],[-62.5,500],[-125,500]]
    }
  }],
  "strip_height": 2280
}
'''
with open('n14_h2280.json','w') as f: f.write(data)

# %% [markdown]
# ## Why Height 2280?
#
# `2280` = strip height for sparrow (scaled by 1000)
#
# **In real coordinates:**
# - 2280 / 1000 = **2.280** (the height constraint)
#
# **Target calculation:**
# - Target score 0.3696 means: `side² / 14 = 0.3696`
# - So target side = `sqrt(0.3696 × 14)` = **2.2747**
# - Scaled: 2274.7
#
# We use 2280 (slightly above 2275) to give sparrow room to optimize. Sparrow minimizes width for a fixed height - if height is too tight, width explodes.
#
# **Trade-off found empirically:**
#
# | Height | Best Width | max(w,h) | Score |
# |--------|------------|----------|-------|
# | 2275   | 2344       | 2344     | 0.392 |
# | 2280   | 2280       | 2280     | 0.371 |
# | 2300   | 2333       | 2333     | 0.389 |
#
# Height **2280** gives the best balance where width ≈ height ≈ 2280.

# %% [markdown]
# ### 2. Run sparrow
#
# Parameters:
# - `-t 600`: 600 seconds optimization time
# - `-s 42`: random seed (try different seeds: 42, 100, 200, etc.)
# - Strip height 2280 found to be optimal for N=14

# %%
# !cd sparrow && cargo run --release --features=simd,only_final_svg -- -i ../n14_h2280.json -t 600 -s 42
# Out:
#     Updating crates.io index
#     Updating git repository `https://github.com/JeroenGar/jagua-rs.git`
#      Locking 119 packages to latest Rust 1.92.0 compatible versionsng             Fetch [========>                        ] 1 complete; 22 pending
#   Downloaded anstream v0.6.21
#   Downloaded anstyle-parse v0.2.7
#   Downloaded byteorder v1.5.0
#   Downloaded anstyle-query v1.1.5
#   Downloaded float-cmp v0.10.0 bytes: 98.1KiB
#   Downloaded anstyle v1.0.13ng bytes: 50.3KiB
#   Downloaded bitflags v2.10.0g bytes: 18.4KiB
#   Downloaded web-time v1.1.0ng bytes: 20.0KiB
#   Downloaded cfg-if v1.0.4ning bytes: 532.8KiB
#   Downloaded matrixmultiply v0.3.10s: 522.8KiB
#   Downloaded utf8parse v0.2.2g bytes: 874.0KiB
#   Downloaded num-traits v0.2.19bytes: 2.8MiB
#   Downloaded numfmt v1.2.0ning bytes: 2.7MiB
#   Downloaded smallvec v1.15.1g bytes: 3.6MiB
#   Downloaded version_check v0.9.5tes: 3.5MiB
#   Downloaded zmij v1.0.14ining bytes: 3.7MiB
#   Downloaded rustc_version v0.4.1tes: 3.7MiB
#   Downloaded svg v0.18.0aining bytes: 3.6MiB
#   Downloaded serde_derive v1.0.228es: 3.3MiB
#   Downloaded rand v0.9.2aining bytes: 2.9MiB
#   Downloaded memchr v2.7.6ning bytes: 2.7MiB
#   Downloaded rand_distr v0.5.1 bytes: 2.5MiB
#   Downloaded nix v0.30.1aining bytes: 2.2MiB
#   Downloaded ndarray v0.17.2ng bytes: 2.0MiB
#   Downloaded libm v0.2.15ining bytes: 1.8MiB
#   Downloaded itertools v0.14.0 bytes: 1.6MiB
#   Downloaded syn v2.0.114ining bytes: 1.5MiB
#   Downloaded clap v4.5.54ining bytes: 1.3MiB
#   Downloaded rayon-core v1.13.0bytes: 1.2MiB
#   Downloaded proc-macro2 v1.0.105tes: 1.0MiB
#   Downloaded jiff v0.2.18ining bytes: 862.6KiB
#   Downloaded libc v0.2.180cting jiff ...
#   Downloaded zerocopy v0.8.33ng libc ...
#   Downloaded serde v1.0.228ing bytes: 467.6KiB
#   Downloaded rayon v1.11.0ning bytes: 398.0KiB
#   Downloaded fern v0.7.1aining bytes: 319.8KiB
#   Downloaded serde_json v1.0.149ytes: 267.8KiB
#   Downloaded geo-buffer v0.2.0 bytes: 247.4KiB
#   Downloaded clap_derive v4.5.49ytes: 215.4KiB
#   Downloaded spin v0.9.8aining bytes: 183.4KiB
#   Downloaded slotmap v1.1.1ing bytes: 143.4KiB
#   Downloaded serde_core v1.0.228ytes: 111.4KiB
#   Downloaded robust v0.2.3ning bytes: 79.4KiB
#   Downloaded geo v0.24.1aining bytes: 18.4KiB
#   Downloaded clap_builder v4.5.54
#   Downloaded jiff-static v0.2.18
#   Downloaded geographiclib-rs v0.2.5
#   Downloaded geo-types v0.7.18
#   Downloaded dtoa v1.0.11
#   Downloaded crossbeam-utils v0.8.21
#   Downloaded cfg_aliases v0.2.1
#   Downloaded stable_deref_trait v1.2.1
#   Downloaded rand_xoshiro v0.7.0
#   Downloaded rand_chacha v0.9.0
#   Downloaded quote v1.0.43
#   Downloaded ppv-lite86 v0.2.21
#   Downloaded hash32 v0.2.1
#   Downloaded getrandom v0.3.4
#   Downloaded either v1.15.0
#   Downloaded crossbeam-epoch v0.9.18
#   Downloaded crossbeam-deque v0.8.6
#   Downloaded clap_lex v0.7.7
#   Downloaded unicode-ident v1.0.22
#   Downloaded test-case-macros v3.3.1
#   Downloaded test-case-core v3.3.1
#   Downloaded tap v1.0.1
#   Downloaded strsim v0.11.1
#   Downloaded scopeguard v1.2.0
#   Downloaded rstar v0.10.0
#   Downloaded rawpointer v0.2.1
#   Downloaded ordered-float v5.1.0
#   Downloaded litrs v1.0.0
#   Downloaded heapless v0.7.17
#   Downloaded rand_core v0.9.5
#   Downloaded num-complex v0.4.6
#   Downloaded num-integer v0.1.46
#   Downloaded colorchoice v1.0.4
#   Downloaded float_next_after v1.0.0
#   Downloaded document-features v0.2.12
#   Downloaded test-case v3.3.1
#   Downloaded log v0.4.29
#   Downloaded lock_api v0.4.14
#   Downloaded semver v1.0.27
#   Downloaded num_cpus v1.17.0
#   Downloaded itoa v1.0.17
#   Downloaded is_terminal_polyfill v1.70.2
#   Downloaded heck v0.5.0
#   Downloaded ctrlc v3.5.1
#   Downloaded anyhow v1.0.100
#   Downloaded autocfg v1.5.0
#   Downloaded approx v0.5.1
#   Downloaded 91 crates (6.3MiB) in 0.72s
#    Compiling autocfg v1.5.0
#    Compiling libm v0.2.15
#    Compiling proc-macro2 v1.0.105
#    Compiling libc v0.2.180
#    Compiling quote v1.0.43            ] 4/130: libm, autocfg, proc-macro2(…
#    Compiling num-traits v0.2.19       ] 5/130: libm, autocfg, quote(build.…
#    Compiling unicode-ident v1.0.22    ] 6/130: libm, quote(build.rs), proc…
#    Compiling cfg-if v1.0.4           ] 11/130: proc-macro2, libm, num-trai…
#    Compiling semver v1.0.27          ] 12/130: proc-macro2, libm, cfg-if, …
#    Compiling rustc_version v0.4.1    ] 13/130: proc-macro2, libm, semver, …
#    Compiling getrandom v0.3.4        ] 15/130: proc-macro2, libm, quote, l…
#    Compiling syn v2.0.114            ] 16/130: libm, quote, getrandom(buil…
#    Compiling scopeguard v1.2.0       ] 17/130: syn, libm, getrandom(build.…
#    Compiling lock_api v0.4.14        ] 18/130: syn, libm, scopeguard, libc
#    Compiling heapless v0.7.17        ] 21/130: syn, getrandom(build), num-…
#    Compiling zerocopy v0.8.33        ] 22/130: syn, heapless(build.rs), nu…
#    Compiling byteorder v1.5.0        ] 23/130: syn, zerocopy(build.rs), nu…
#    Compiling crossbeam-utils v0.8.21 ] 24/130: syn, byteorder, num-traits,…
#    Compiling hash32 v0.2.1           ] 26/130: syn, getrandom, crossbeam-u…
#    Compiling spin v0.9.8             ] 30/130: syn, hash32, heapless(build…
#    Compiling stable_deref_trait v1.2.1 31/130: syn, hash32, spin, getrandom
#    Compiling rand_core v0.9.5        ] 32/130: syn, spin, getrandom, stabl…
#    Compiling serde_core v1.0.228     ] 36/130: syn, heapless, zerocopy, cr…
#    Compiling smallvec v1.15.1        ] 37/130: syn, zerocopy, crossbeam-ut…
#    Compiling crossbeam-epoch v0.9.18 ] 39/130: syn, smallvec, serde_core(b…
#    Compiling rstar v0.10.0           ] 40/130: syn, smallvec, crossbeam-ep…
#    Compiling approx v0.5.1           ] 41/130: syn, rstar, crossbeam-epoch…
#    Compiling matrixmultiply v0.3.10  ] 42/130: syn, rstar, zerocopy, approx
#    Compiling rayon-core v1.13.0      ] 43/130: syn, rstar, zerocopy, matri…
#    Compiling cfg_aliases v0.2.1      ] 44/130: syn, rstar, rayon-core(buil…
#    Compiling version_check v0.9.5    ] 45/130: syn, rayon-core(build.rs), …
#    Compiling utf8parse v0.2.2        ] 46/130: syn, version_check, zerocop…
#    Compiling log v0.4.29             ] 47/130: syn, version_check, utf8par…
#    Compiling anstyle-parse v0.2.7    ] 48/130: syn, version_check, log, ze…
#    Compiling slotmap v1.1.1          ] 49/130: syn, version_check, anstyle…
#    Compiling nix v0.30.1             ] 50/130: syn, anstyle-parse, zerocop…
#    Compiling geo-types v0.7.18       ] 52/130: syn, nix(build.rs), zerocop…
#    Compiling ppv-lite86 v0.2.21      ] 53/130: syn, nix(build.rs), geo-typ…
#    Compiling crossbeam-deque v0.8.6  ] 55/130: syn, geo-types, matrixmulti…
#    Compiling geographiclib-rs v0.2.5 ] 57/130: syn, serde_core, geo-types,…
#    Compiling rand_chacha v0.9.0      ] 58/130: syn, serde_core, geographic…
#    Compiling serde v1.0.228          ] 59/130: syn, serde_core, geographic…
#    Compiling zmij v1.0.14            ] 61/130: syn, serde_core, cfg-if, se…
#    Compiling colorchoice v1.0.4      ] 62/130: syn, serde_core, serde(buil…
#    Compiling anstyle-query v1.1.5    ] 63/130: syn, serde_core, colorchoic…
#    Compiling is_terminal_polyfill v1.70.2/130: syn, serde_core, anstyle-qu…
#    Compiling anstyle v1.0.13         ] 65/130: syn, serde_core, anstyle-qu…
#    Compiling float_next_after v1.0.0 ] 66/130: syn, serde_core, anstyle, i…
#    Compiling rawpointer v0.2.1       ] 67/130: syn, serde_core, anstyle, f…
#    Compiling either v1.15.0          ] 68/130: syn, serde_core, anstyle, r…
#    Compiling robust v0.2.3           ] 69/130: syn, serde_core, either, an…
#    Compiling anyhow v1.0.100         ] 70/130: syn, serde_core, either, ro…
#    Compiling geo v0.24.1>            ] 72/130: syn, serde_core, robust, an…
#    Compiling anstream v0.6.21        ] 73/130: syn, serde_core, geo, anyho…
#    Compiling serde_derive v1.0.228   ] 75/130: syn, serde_core, matrixmult…
#    Compiling test-case-core v3.3.1   ] 78/130: serde(build), matrixmultipl…
#    Compiling rand v0.9.2=>           ] 79/130: test-case-core, matrixmulti…
#    Compiling num-complex v0.4.6      ] 83/130: slotmap(build), rand, rayon…
# m    Building [===============>          ] 84/130: slotmap(build), num-complex…   Compiling num-integer v0.1.46
#    Compiling bitflags v2.10.0        ] 85/130: num-complex, num-integer, r…
#    Compiling litrs v1.0.0==>         ] 86/130: num-complex, bitflags, rayo…
#    Compiling heck v0.5.0===>         ] 87/130: bitflags, litrs, rayon-core…
#    Compiling strsim v0.11.1>         ] 88/130: bitflags, litrs, rayon-core…
#    Compiling itoa v1.0.17==>         ] 89/130: strsim, litrs, rayon-core, …
#    Compiling clap_lex v0.7.7>        ] 90/130: strsim, litrs, rayon-core, …
#    Compiling serde_json v1.0.149     ] 91/130: strsim, clap_lex, litrs, it…
#    Compiling document-features v0.2.12 92/130: strsim, clap_lex, litrs, se…
#    Compiling clap_builder v4.5.54    ] 94/130: strsim, clap_lex, document-…
#    Compiling clap_derive v4.5.49     ] 95/130: strsim, clap_lex, clap_buil…
#    Compiling ndarray v0.17.2=>       ] 98/130: serde, nix, clap_builder, c…
#    Compiling rayon v1.11.0===>       ] 99/130: nix, ndarray, clap_builder,…
#    Compiling rand_distr v0.5.1      ] 101/130: ndarray, rayon, clap_builde…
#    Compiling geo-buffer v0.2.0      ] 102/130: ndarray, rayon, clap_builde…
#    Compiling test-case-macros v3.3.1] 103/130: geo-buffer, ndarray, rayon,…
#    Compiling itertools v0.14.0>     ] 106/130: geo-buffer, ndarray, clap_b…
#    Compiling float-cmp v0.10.0>     ] 107/130: ndarray, itertools, clap_bu…
#    Compiling ordered-float v5.1.0   ] 108/130: float-cmp, ndarray, itertoo…
#    Compiling dtoa v1.0.11=====>     ] 109/130: ordered-float, ndarray, ite…
#    Compiling svg v0.18.0=======>    ] 110/130: ndarray, itertools, clap_bu…
#    Compiling web-time v1.1.0===>    ] 111/130: ndarray, itertools, clap_bu…
#    Compiling memchr v2.7.6=====>    ] 112/130: ndarray, web-time, clap_bui…
#    Compiling numfmt v1.2.0=====>    ] 113/130: ndarray, memchr, clap_build…
#    Compiling test-case v3.3.1==>    ] 114/130: ndarray, memchr, numfmt, svg
#    Compiling clap v4.5.54=======>   ] 116/130: serde_json, ndarray, memchr…
#    Compiling ctrlc v3.5.1=======>   ] 117/130: clap, serde_json, ndarray, …
#    Compiling jagua-rs v0.6.4 (https://github.com/JeroenGar/jagua-rs.git?rev=76aab0fa70688ee50d1809f5376f71c758ea0b7c#76aab0fa)
#    Compiling fern v0.7.1========>   ] 119/130: serde_json, ndarray, memchr…
#    Compiling rand_xoshiro v0.7.0=>  ] 120/130: serde_json, memchr, jagua-r…
#    Compiling num_cpus v1.17.0====>  ] 121/130: serde_json, jagua-rs, fern,…
#    Compiling jiff v0.2.18========>  ] 122/130: serde_json, jagua-rs, fern,…
#    Compiling tap v1.0.1==========>  ] 123/130: serde_json, jiff, jagua-rs,…
#    Compiling sparrow v0.1.0 (/kaggle/working/sparrow)
# error[E0554]: `#![feature]` may not be used on the stable release channel
#  --> src/lib.rs:1:31
#   |
# 1 | #![cfg_attr(feature = "simd", feature(portable_simd))]
#   |                               ^^^^^^^^^^^^^^^^^^^^^^
#
# For more information about this error, try `rustc --explain E0554`.
# error: could not compile `sparrow` (lib) due to 1 previous error
# warning: build failed, waiting for other jobs to finish...
# m    Building [=======================> ] 128/130: jiff

# %%
from IPython.display import SVG, display
display(SVG('/kaggle/working/sparrow/output/final_n14_h2280.svg'))
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# /tmp/ipykernel_55/4096517893.py in <cell line: 0>()
#       1 from IPython.display import SVG, display
# ----> 2 display(SVG('/kaggle/working/sparrow/output/final_n14_h2280.svg'))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     628         # subclasses ensure url and filename are set
#     629         # before assigning to self.data
# --> 630         self.data = data
#     631
#     632         if metadata is not None:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in data(self, svg)
#     782         # parse into dom object
#     783         from xml.dom import minidom
# --> 784         x = minidom.parseString(svg)
#     785         # get svg tag (should be 1)
#     786         found_svg = x.getElementsByTagName('svg')
#
# /usr/lib/python3.12/xml/dom/minidom.py in parseString(string, parser)
#    1998     if parser is None:
#    1999         from xml.dom import expatbuilder
# -> 2000         return expatbuilder.parseString(string)
#    2001     else:
#    2002         from xml.dom import pulldom
#
# /usr/lib/python3.12/xml/dom/expatbuilder.py in parseString(string, namespaces)
#     920     else:
#     921         builder = ExpatBuilder()
# --> 922     return builder.parseString(string)
#     923
#     924
#
# /usr/lib/python3.12/xml/dom/expatbuilder.py in parseString(self, string)
#     218         parser = self.getParser()
#     219         try:
# --> 220             parser.Parse(string, True)
#     221             self._setup_subset(string)
#     222         except ParseEscape:
#
# ExpatError: not well-formed (invalid token): line 1, column 0

# %%
# !cp /kaggle/input/santa-submission/submission.csv submission.csv

# %%
"""Merge sparrow solution into submission.csv if score is better."""

import json
import sys
import math
from pathlib import Path

SCALE = 1000.0

# Tree polygon vertices
TREE_VERTS = [
    (0.0, 0.8), (0.125, 0.5), (0.0625, 0.5), (0.2, 0.25), (0.1, 0.25),
    (0.35, 0.0), (0.075, 0.0), (0.075, -0.2), (-0.075, -0.2), (-0.075, 0.0),
    (-0.35, 0.0), (-0.1, 0.25), (-0.2, 0.25), (-0.0625, 0.5), (-0.125, 0.5)
]

def transform_point(x, y, tx, ty, deg):
    rad = math.radians(deg)
    c, s = math.cos(rad), math.sin(rad)
    rx = x * c - y * s
    ry = x * s + y * c
    return rx + tx, ry + ty

def calc_score(placements):
    """Calculate score from placements [(x, y, deg), ...]"""
    min_x = min_y = float('inf')
    max_x = max_y = float('-inf')

    for tx, ty, deg in placements:
        for vx, vy in TREE_VERTS:
            px, py = transform_point(vx, vy, tx, ty, deg)
            min_x = min(min_x, px)
            max_x = max(max_x, px)
            min_y = min(min_y, py)
            max_y = max(max_y, py)

    width = max_x - min_x
    height = max_y - min_y
    side = max(width, height)
    return side ** 2 / len(placements)

def load_submission(csv_path):
    """Load submission.csv into dict {id: (x, y, deg)}"""
    data = {}
    with open(csv_path) as f:
        header = f.readline()  # skip header
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = line.split(',')
            id_ = parts[0]
            x = float(parts[1][1:])  # remove 's' prefix
            y = float(parts[2][1:])
            deg = float(parts[3][1:])
            data[id_] = (x, y, deg)
    return data

def extract_group(data, group):
    """Extract placements for a specific group (e.g., '014')"""
    placements = []
    i = 0
    while f"{group}_{i}" in data:
        placements.append(data[f"{group}_{i}"])
        i += 1
    return placements

def load_sparrow(json_path):
    """Load placements from sparrow JSON output"""
    with open(json_path) as f:
        data = json.load(f)

    sol = data.get('solution', data)
    placements = []

    for item in sol['layout']['placed_items']:
        t = item['transformation']
        x = t['translation'][0] / SCALE
        y = t['translation'][1] / SCALE
        rot = t['rotation']
        placements.append((x, y, rot))

    return placements

def merge(submission_path, sparrow_json, group="014", output_path=None):
    """Merge sparrow solution if better than existing."""

    # Load existing submission
    data = load_submission(submission_path)

    # Get existing group score
    old_placements = extract_group(data, group)
    if not old_placements:
        print(f"Error: Group {group} not found in {submission_path}")
        return False

    old_score = calc_score(old_placements)
    print(f"Existing score for {group}: {old_score:.6f}")

    # Get new sparrow score
    new_placements = load_sparrow(sparrow_json)
    new_score = calc_score(new_placements)
    print(f"New sparrow score:        {new_score:.6f}")

    if new_score >= old_score:
        print(f"\nNo improvement. Keeping existing solution.")
        return False

    improvement = old_score - new_score
    print(f"\nImprovement: {improvement:.6f} ({improvement/old_score*100:.2f}%)")

    # Merge: replace group entries
    for i, (x, y, deg) in enumerate(new_placements):
        data[f"{group}_{i}"] = (x, y, deg)

    # Write output
    out_path = output_path or submission_path

    # Sort keys properly (by group, then index)
    def sort_key(k):
        parts = k.split('_')
        return (parts[0], int(parts[1]))

    sorted_keys = sorted(data.keys(), key=sort_key)

    with open(out_path, 'w') as f:
        f.write("id,x,y,deg\n")
        for k in sorted_keys:
            x, y, deg = data[k]
            f.write(f"{k},s{x:.17f},s{y:.17f},s{deg:.17f}\n")

    print(f"Merged! Saved to {out_path}")

merge('submission.csv', 'sparrow/output/final_n14_h2280.json', "014")
# Out:
# Existing score for 014: 0.371478
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_55/2645898511.py in <cell line: 0>()
#     132     print(f"Merged! Saved to {out_path}")
#     133
# --> 134 merge('submission.csv', 'sparrow/output/final_n14_h2280.json', "014")
#
# /tmp/ipykernel_55/2645898511.py in merge(submission_path, sparrow_json, group, output_path)
#      99
#     100     # Get new sparrow score
# --> 101     new_placements = load_sparrow(sparrow_json)
#     102     new_score = calc_score(new_placements)
#     103     print(f"New sparrow score:        {new_score:.6f}")
#
# /tmp/ipykernel_55/2645898511.py in load_sparrow(json_path)
#      68 def load_sparrow(json_path):
#      69     """Load placements from sparrow JSON output"""
# ---> 70     with open(json_path) as f:
#      71         data = json.load(f)
#      72
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sparrow/output/final_n14_h2280.json'

# %%
# !cp -r /kaggle/working/sparrow/output output
# !rm -r /kaggle/working/sparrow
